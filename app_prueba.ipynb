# %%
import requests

# %%
# Definir endpoint
url = 'http://127.0.0.1:8000/upload-excel'

# Definir path del Excel
file_path = "test.xlsx"
files = {"file": open(file_path, "rb")}

# Hacer la solicitud POST
response = requests.post(url=url, files=files)

# Verificar el código de estado y la respuesta
print(response.status_code)
if response.status_code == 200:
    print(response.json())
else:
    print("Error en la solicitud:", response.text)
# Out:
# 200
# {'predictions': [634.4336255735911, 436.3335118256731, 434.6278387303772, 559.6651311763553, 576.9613857714378, 545.1954986286077, 509.26309168865805, 491.47045713411853, 532.1809837885471, 467.9748464289112, 471.02137415967707, 373.7978252225382, 468.7841898694255, 438.1638532100741, 432.23161712045885, 495.0215296216461, 466.6177890057876, 540.5440878474723, 506.52420910457136, 616.631573071995, 473.1790783886628, 364.3397069661713, 449.81604517696405, 356.81256786345966, 375.89177876268286, 535.1120502547901, 481.1906411826187, 495.736209955492, 483.8001697026432, 505.0133655643465, 551.5988132173752, 451.209544549166, 514.5103113935955, 491.8564171610484, 400.4147451614257, 479.3825521674171, 459.83781480020946, 430.97126581685575, 534.6231218024345, 465.5609827784857, 571.264416928974, 439.74376204568193, 590.5397257717082, 634.106795666251, 359.9610149162919, 450.5530607644372, 409.4056829276327, 483.2555249639938, 679.7445134753902, 384.65578645724906, 495.06082409587475, 453.82649643232764, 626.395564549611, 633.5776174187708, 568.1420254383095, 364.386522786941, 623.2131375096433, 601.420076066001, 490.86447327129076, 495.57808854996676, 308.8540875589209, 451.56957737602204, 334.3269635504788, 477.45357108490214, 641.6948335835675, 495.81386993163244, 597.3225732283488, 415.74212533424134, 483.1633167624366, 459.5661611183791, 363.71409377214945, 497.2885786250539, 580.0980830421177, 560.0335206481075, 530.3823245187551]}
